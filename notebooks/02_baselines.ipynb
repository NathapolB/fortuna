# %% [markdown]
# # 02 — Baselines: Frequency & Markov Sanity Checks
#
# **Project Fortuna — Phase 2**
#
# Stub notebook. Will implement FrequencyBayesian and MarkovChain baseline models in Phase 2.

# %%
print('Phase 2 stub — implement after FrequencyBayesian and MarkovChain models are built')
